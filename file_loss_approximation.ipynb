# %% [markdown]
# # File loss approximation
#
# In this notebook, we focus on the question of the approximation of the calculation of the file loss probability. The first part is dedicated to motivations. Then, in the second subsection, we give the formula used for the approximation. Finaly we try to estimate the error between the approximation and the exact formula.
#
# ## Motivation
#
# ## Approximation
#
# ## Error estimation
#    To perform an error aproximation, we need to do some assumptions.

# %%
import file_loss as fl
from pandas import DataFrame

def launch_experiment(disks, chunk_count, threshold_recovery, spread_factor, experiment, delta, mean_reliability):
    """
    Args:
        disks (list):
        chunk_count (int):
        threshold_recovery (int):
        spread_factor (int):
        experiences (list):
        delta (double):
        mean_reliability (double):
        
    Returns:
    """
    
    # Approximated file loss probability
    reliability_mean_value = fl.probability_at_least_d_fail_equal_reliability(threshold_recovery, chunk_count, mean_reliability)
    print("----------------------------------------------------------------------")
    print("                  Approximated file loss probability                  ")
    print(reliability_mean_value)
    print("----------------------------------------------------------------------")
    
    # Exact reliability dataframe
    print("----------------------------------------------------------------------")
    print("                     Exact file loss probability                     ")
    reliabilities = DataFrame(fl.file_loss_delta_matrix(delta, mean_reliability, experiment, disks, chunk_count, spread_factor, 
                                                        threshold_recovery)
                              , columns=['Reliability'])
    
    # Histogram of reliabilities
    reliabilities.hist(bins=50)
    
    # Mean value and standard deviation of the dataframe reliabilities
    print "Mean value of reliabilities : ",reliabilities.mean()
    print("")
    print "Standard deviation of reliabilities : ",reliabilities.std()

    # relative error
    relative_error_list = abs(reliabilities - reliability_mean_value)/abs(reliabilities)
    
    # absolute error
    absolute_error_list = abs(reliabilities - reliability_mean_value)

    # relative error plot
    relative_error_list.plot(title='Relative erros plot')
    
    # relative error histogram
    relative_error_list.hist(bins=50)

    # absolute error plot
    absolute_error_list.plot(title='Absolute errors plot')
    
    # absolute error histogram
    absolute_error_list.hist(bins=50)
    
    print("----------------------------------------------------------------------")

# %% [markdown]
# ### $\Delta = 10^{-4}$
# #### $m = 1000$
# ##### s = n-1

# %%
# Parameters
m = 1000 # The number of disks in the system
disks = range(m)

n = 12 # number of chunks
d = 3 # number of chunks until the file is lost
spread_factor = 11 # spread factor

experience_count = 2000 # The number of experiments
experiment = range(experience_count)

delta = 0.0001
mean_reliability = 0.999

launch_experiment(disks, n, d, spread_factor, experiment, delta, mean_reliability)
# Out:
# ----------------------------------------------------------------------
#                   Approximated file loss probability
# 2.18519742772e-07
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
#                      Exact file loss probability
# Mean value of reliabilities :
#  Reliability    0
# dtype: float64
#
# Standard deviation of reliabilities :  Reliability    9.888797e-12
# dtype: float64
# ----------------------------------------------------------------------

# %% [markdown]
# ##### $s = 2n$

# %%
# Parameters
m = 1000 # The number of disks in the system
disks = range(m)

n = 12 # number of chunks
d = 3 # number of chunks until the file is lost
spread_factor = 24 # spread factor

experience_count = 2000 # The number of experiments
experiment = range(experience_count)

delta = 0.0001
mean_reliability = 0.999

launch_experiment(disks, n, d, spread_factor, experiment, delta, mean_reliability)

# %% [markdown]
# ##### $s = m/2$

# %%
# Parameters
m = 1000 # The number of disks in the system
disks = range(m)

n = 12 # number of chunks
d = 3 # number of chunks until the file is lost
spread_factor = 450 # spread factor

experience_count = 2000 # The number of experiments
experiment = range(experience_count)

delta = 0.0001
mean_reliability = 0.999

launch_experiment(disks, n, d, spread_factor, experiment, delta, mean_reliability)

# %% [markdown]
# #### $m = 2000$
# ##### $s = n-1$

# %%
# Parameters
m = 2000 # The number of disks in the system
disks = range(m)

n = 12 # number of chunks
d = 3 # number of chunks until the file is lost
spread_factor = 11 # spread factor

experience_count = 1000 # The number of experiments
experiment = range(experience_count)

delta = 0.0001
mean_reliability = 0.999

launch_experiment(disks, n, d, spread_factor, experiment, delta, mean_reliability)

# %% [markdown]
# ##### $s = 2n$

# %%
# Parameters
m = 2000 # The number of disks in the system
disks = range(m)

n = 12 # number of chunks
d = 3 # number of chunks until the file is lost
spread_factor = 24 # spread factor

experience_count = 1000 # The number of experiments
experiment = range(experience_count)

delta = 0.0001
mean_reliability = 0.999

launch_experiment(disks, n, d, spread_factor, experiment, delta, mean_reliability)

# %% [markdown]
# #### $m = 3000$
# ##### $s = n - 1$

# %%
# Parameters
m = 3000 # The number of disks in the system
disks = range(m)

n = 12 # number of chunks
d = 3 # number of chunks until the file is lost
spread_factor = 11 # spread factor

experience_count = 1000 # The number of experiments
experiment = range(experience_count)

delta = 0.0001
mean_reliability = 0.999

launch_experiment(disks, n, d, spread_factor, experiment, delta, mean_reliability)

# %% [markdown]
# ##### $s = 2n$

# %%
# Parameters
m = 3000 # The number of disks in the system
disks = range(m)

n = 12 # number of chunks
d = 3 # number of chunks until the file is lost
spread_factor = 24 # spread factor

experience_count = 1000 # The number of experiments
experiment = range(experience_count)

delta = 0.0001
mean_reliability = 0.999

launch_experiment(disks, n, d, spread_factor, experiment, delta, mean_reliability)

# %%
def sigma(delta):
    return sig
